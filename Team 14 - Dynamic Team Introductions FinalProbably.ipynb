# %%
## Project Code 3.5.2 ##

# Design your mad lib here!

############### Defining Variables & Requesting Input ########################


# The user has to input some data based on the hint or category given, without

# Assigning every variable as the user inputs the answer
print(f"""
{'-' * 40}

Hi all, we have created a little something for you guys to get to know us better.

Please help us fill some of these missing variables.

Are you ready? [Press Enter]

""")
input(prompt="> ")
# Inititalising prompts and lowercasing where required
age = input(prompt="Number:\t\t\t\t\t").lower()
city = input(prompt="City:\t\t\t\t\t")
time = (input(prompt="Number of hours:\t\t\t")).lower()
transport = (input(prompt="Mode of transport:\t\t\t")).lower()
hobby =(input(prompt="Hobby:\t\t\t\t\t")).lower()
verb = (input(prompt="Verb (ending in -ing):\t\t\t")).lower()
food = (input(prompt="Food:\t\t\t\t\t")).lower()
drink = (input(prompt="Drink:\t\t\t\t\t")).lower()
# Handling exception for day of the week
while True:
    day = (input(prompt="Day of the week (eg. Monday):\t\t")).lower()
    if (day == "monday" or  day == "tuesday" or day == "wednesday" 
        or day == "thursday" or day == "friday" or day == "" 
        or day == "saturday"  or day == "sunday"):
        break
    else:
        print("\nIncorrect day entered. Try Again.\n")


color = (input(prompt="Color:\t\t\t\t\t")).lower()

# Capitilising city name and day of the week
city = city[0].upper()+city[1:].lower()
day = day[0].upper()+day[1:].lower()
#Adding an 's' to the day of the week to make it plural
day = day + "s"





############################## Printing ######################################

#Once the user inputs all of our variables, 
print(f"""
{'-' * 40}

Thanks! You've helped us create our introductions:

We are Team 14, but we call ourselves Fourteam! 

Our team consists of Raafi, Nicola, Zhuomin and Ali! We are all roughly {age} 
years old. We come from Bangladesh, Italy, China, and Pakistan, respectively.

Most of us are already on campus in Boston. Unfortunately, one of us is still 
stuck in {city}, because of visa complications. It will take him {time} hours 
to arrive to Boston if he travels via {transport}. 

Fortunately, we all have very similar interests and hobbies including Computer
Science, Business Intelligence, and {hobby}. We love sharing {food} and 
{drink} while we are {verb}.

We are super excited to join all of you in this adventure! Hope to meet you 
all soon.

P.S. You can join our squad only if you can fill this out correctly: "On 
{day}, we wear {color}!"

Scroll down to view our real story!

{'-' * 40}\n""")
# Out:
# ----------------------------------------
#
# Hi all, we have created a little something for you guys to get to know us better.
#
# Please help us fill some of these missing variables.
#
# Are you ready? [Press Enter]
#
#
# > vwf
# Number:					fwewefwef
# City:					fwevewfwef
# Number of hours:			efwefwefwef
# Mode of transport:			efwefwefwfwe
# Hobby:					fwefwefwfwef
# Verb (ending in -ing):			wefwefwefwef
# Food:					wefwefwefwefw
# Drink:					fwfwefwefwefw
# Day of the week (eg. Monday):		fwefwefwfw
#
# Incorrect day entered. Try Again.
#
# Day of the week (eg. Monday):		wefwef
#
# Incorrect day entered. Try Again.
#
# Day of the week (eg. Monday):		wednesday
# Color:					pink
#
# ----------------------------------------
#
# Thanks! You've helped us create our introductions:
#
# We are Team 14, but we call ourselves Fourteam!
#
# Our team consists of Raafi, Nicola, Zhuomin and Ali! We are all roughly fwewefwef
# ...

# %% [markdown]
# VD----------------------------------------
#
# We are Team 14, but we call ourselves Fourteam!
#
# Our team consists of Raafi, Nicola, Zhuomin and Ali! We are all roughly 23
# years old. We come from Bangladesh, Italy, China, and Pakistan, respectively.
#
# Most of us are already on campus in Boston. Unfortunately, one of us is still
# stuck in Islamabad, because of visa complications. It will take him 13 hours
# to arrive to Boston if he travels via Plane.
#
# Fortunately, we all have very similar interests and hobbies including Computer
# Science, Business Intelligence, and Hiking. We love sharing pasta and
# wine while we are chilling.
#
# We are super excited to join all of you in this adventure! Hope to meet you
# all soon.
#
# P.S. You can join our squad only if you can fill fill this out correctly: "On
# Wednesday, we wear pink!"
#
# ----------------------------------------
